# %% [markdown]
# ---
# # Python Programming Challenges (Cognizant)
# ---

# %% [markdown]
# ![image.png](attachment:3da4b3c3-1d2a-42a7-93b8-c75923537d8f.png)

# %%
name = input("Enter the name:")
pHrint(f'Hello {name}! Welcome to our planet Earth.')
# Out:
# Enter the name: Naoto
# Hello Naoto! Welcome to our planet Earth.

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:d263db22-b248-47e1-ade7-65770c26d3ea.png)

# %%
# set values for testing purposes
age = 50
income = 250_000

# %%
# create the body of the function here
# check invalid responses first
if age < 18 or age > 100:
    print('Invalid Age')
if income < 0:
    print('Invalid Income')

# now run through each scenario
if age <= 60:
    if income <= 250_000:
        tax_rate = 0.0
    elif income > 250_000 and income <= 500_000:
        tax_rate = 0.10
    elif income > 500_000 and income <= 1_000_000:
        tax_rate = 0.20
    elif income > 1_000_000:
        tax_rate = 0.30
    else:
        print('We are outside conditions')
elif age > 60 and age <= 80:
    if income <= 300_000:
        tax_rate = 0.0
    elif income > 300_000 and income <= 500_000:
        tax_rate = 0.10
    elif income > 500_000 and income < 1_000_000:
        tax_rate = 0.20
    elif income > 1_000_000:
        tax_rate = 0.30
    else:
        print('We are outside conditions')
elif age > 80:
    if income <= 500_000:
        tax_rate = 0.0
    elif income > 500_000 and income < 1_000_000:
        tax_rate = 0.20
    elif income > 1_000_000:
        tax_rate = 0.30
    else:
        print('We are outside conditions')
else:
    print('We are outside conditions')

# calculate and print final income tax value

income_tax = tax_rate * income
print(f'The tax amount is: {income_tax}')
# Out:
# The tax amount is: 0.0

# %%
# put into a function and test
def income_tax():
    
    age = int(input("Enter the age:"))
    
    if age < 18 or age > 100:
        return('Invalid Age')
    
    income = int(input("Enter the income:"))
    if income < 0:
        return('Invalid Income')

    # now run through each scenario
    if age <= 60:
        if income <= 250_000:
            tax_rate = 0.0
        elif income > 250_000 and income <= 500_000:
            tax_rate = 0.10
        elif income > 500_000 and income <= 1_000_000:
            tax_rate = 0.20
        elif income > 1_000_000:
            tax_rate = 0.30
        else:
            print('We are outside conditions')
    elif age > 60 and age <= 80:
        if income <= 300_000:
            tax_rate = 0.0
        elif income > 300_000 and income <= 500_000:
            tax_rate = 0.10
        elif income > 500_000 and income <= 1_000_000:
            tax_rate = 0.20
        elif income > 1_000_000:
            tax_rate = 0.30
        else:
            print('We are outside conditions')
    elif age > 80:
        if income <= 500_000:
            tax_rate = 0.0
        elif income > 500_000 and income <=i 1_000_000:
            tax_rate = 0.20
        elif income > 1_000_000:
            tax_rate = 0.30
        else:
            print('We are outside conditions')
    else:
        print('We are outside conditions')

    # calculate and print final income tax value

    income_tax = tax_rate * income
    return(f'The tax amount is: {income_tax:.2f}')

# %%
income_tax()
# Out:
# Enter the age: 50
# Enter the income: 500000
# 'The tax amount is: 50000.00'

# %% [markdown]
# ---

# %%
pal = 'Was it a rat i saw'

# %%
pal.lower()[::-1]
# Out:
# 'was i tar a ti saw'

# %%
pal[::-1].lower()
# Out:
# 'mada'

# %%
pal
# Out:
# 'Was it a rat i saw'

# %%
pal = pal.replace(' ', '')

# %%
pal.lower()[::-1]
# Out:
# 'wasitaratisaw'

# %%
pal
# Out:
# 'Wasitaratisaw'

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:c97d3f9f-3413-4d85-a90e-1df3b82d0319.png)

# %%
# get number of students from user
n = int(input('Enter the no of student details to be created: '))
# check to make sure the number of students is valid
if n <= 0:
    print('Invalid Input')
# create an empty list
student_details = []
# iterate through number of students and append a dictioinary to the list each iteration
for student in range(n):
    name = input('Name: ')
    age = int(input('Age: '))
    # check for valid age entry here
    if age <= 10 or age > 20:
        print('Invalid Input')
        break
    location = input('Location: ')
    student_details.append({'Name' : name, 'Age' : age, 'Location' : location})
print(f"Here's the list of student details:\n{student_details}")
# create list of locations 
loc_list = []
# for student in student_details:
#     loc_list.append(student['Location'])
[loc_list.append(student['Location']) for student in student_details]
loc = input('Enter the training location: ')
# make sure location is present in list
if loc not in loc_list:
    print('Invalid Location')
for student in student_details:
    if student['Location'] == loc:
        print(student['Name'])
# Out:
# Enter the no of student details to be created:  3
# Name:  Logan
# Age:  11
# Location:  Utah
# Name:  Josh
# Age:  13
# Location:  Utah
# Name:  Jose
# Age:  14
# Location:  Phoenix
# Here's the list of student details:
# [{'Name': 'Logan', 'Age': 11, 'Location': 'Utah'}, {'Name': 'Josh', 'Age': 13, 'Location': 'Utah'}, {'Name': 'Jose', 'Age': 14, 'Location': 'Phoenix'}]
# Enter the training location:  Utah
# Logan
# Josh

# %%
# make into a function
def student_deets():
    # get number of students from user
    n = int(input('Enter the no of student details to be created: '))
    # check to make sure the number of students is valid
    if n <= 0:
        return('Invalid Input')
    # create an empty list
    student_details = []
    # iterate through number of students and append a dictioinary to the list each iteration
    for student in range(n):
        name = input('Name: ')
        age = int(input('Age: '))
        # check for valid age entry here
        if age <= 10 or age > 20:
            return('Invalid Input')
        location = input('Location: ')
        student_details.append({'Name' : name, 'Age' : age, 'Location' : location})
    print(f"Here's the list of student details:\n{student_details}")
    # create list of locations 
    loc_list = []
    # add locations present to list
    [loc_list.append(student['Location']) for student in student_details]
    loc = input('Enter the training location: ')
    # make sure location is present in list
    if loc not in loc_list:
        return('Invalid Location')
#     for student in student_details:
#         if student['Location'] == loc:
#             print(student['Name'])
    [print()]

# %%
student_deets()
# Out:
# Enter the no of student details to be created:  3
# Name:  John
# Age:  11
# Location:  Utah
# Name:  Mike
# Age:  12
# Location:  Utah
# Name:  Jose
# Age:  14
# Location:  Phoenix
# Here's the list of student details:
# [{'Name': 'John', 'Age': 11, 'Location': 'Utah'}, {'Name': 'Mike', 'Age': 12, 'Location': 'Utah'}, {'Name': 'Jose', 'Age': 14, 'Location': 'Phoenix'}]
# Enter the training location:  Utah
# John
# Mike

# %% [markdown]
# ![image.png](attachment:dbe32fd1-698c-4049-8882-71a8872ed68c.png)
# ![image.png](attachment:3b2b8c99-d773-4881-88fd-483e9dfc3141.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:15479219-620d-476d-9874-b79b9de678c2.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:3ea1376f-c11e-48da-b956-ad754bd33802.png)
